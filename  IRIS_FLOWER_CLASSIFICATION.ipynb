# %% [markdown]
# # importing the required libraires

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# # Loading the dataset

# %%
dataframe = pd.read_csv("Iris.csv")

# %% [markdown]
# # Exploratory Data Analysis

# %%
dataframe.plot.scatter(x='SepalLengthCm',y='Species',c = '#17becf')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Species'>

# %%
dataframe.plot.scatter(x='SepalWidthCm',y='Species',c = '#17becf')
# Out:
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='Species'>

# %%
dataframe.plot.scatter(x='PetalWidthCm',y='Species',c = '#17becf')
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='Species'>

# %%
dataframe.plot.scatter(x='PetalLengthCm',y='Species',c = '#17becf')
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Species'>

# %%
'''Thus we come to a conclusion that the dataset is linerly seperable'''
# Out:
# 'Thus we come to a conclusion that the dataset is linerly seperable'

# %%
dataframe.shape
# Out:
# (150, 6)

# %%
print(dataframe.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
dataframe.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
dataframe.value_counts()
# Out:
# Id   SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 1    5.1            3.5           1.4            0.2           Iris-setosa        1
# 95   5.6            2.7           4.2            1.3           Iris-versicolor    1
# 97   5.7            2.9           4.2            1.3           Iris-versicolor    1
# 98   6.2            2.9           4.3            1.3           Iris-versicolor    1
# 99   5.1            2.5           3.0            1.1           Iris-versicolor    1
#                                                                                  ..
# 51   7.0            3.2           4.7            1.4           Iris-versicolor    1
# 52   6.4            3.2           4.5            1.5           Iris-versicolor    1
# 53   6.9            3.1           4.9            1.5           Iris-versicolor    1
# 54   5.5            2.3           4.0            1.3           Iris-versicolor    1
# ...

# %% [markdown]
# # Checking for NAN number and handling them if any

# %%
dataframe["SepalLengthCm"].isnull().sum()
# Out:
# 0

# %%
dataframe["SepalWidthCm"].isnull().sum()
# Out:
# 0

# %%
dataframe["PetalLengthCm"].isnull().sum()
# Out:
# 0

# %%
dataframe["PetalWidthCm"].isnull().sum()
# Out:
# 0

# %%
"""Thus we come to the conclusion that every column is having no NAN number.Thus we can proceed with the train_test_split"""
# Out:
# 'Thus we come to the conclusion that every column is having no NAN number.Thus we can proceed with the train_test_split'

# %%
dataframe.shape
# Out:
# (150, 6)

# %% [markdown]
# # Train Test Split

# %%
X = dataframe.drop(["Id","Species"],axis ='columns')

# %%
y=dataframe["Species"]

# %%
X.head(),X.shape
# Out:
# (   SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
#  0            5.1           3.5            1.4           0.2
#  1            4.9           3.0            1.4           0.2
#  2            4.7           3.2            1.3           0.2
#  3            4.6           3.1            1.5           0.2
#  4            5.0           3.6            1.4           0.2,
#  (150, 4))

# %%
y.head(),y.shape
# Out:
# (0    Iris-setosa
#  1    Iris-setosa
#  2    Iris-setosa
#  3    Iris-setosa
#  4    Iris-setosa
#  Name: Species, dtype: object,
#  (150,))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size = 0.8,test_size = 0.2,random_state =2)

# %%
X_train.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 126            6.2           2.8            4.8           1.8
# 23             5.1           3.3            1.7           0.5
# 64             5.6           2.9            3.6           1.3
# 117            7.7           3.8            6.7           2.2
# 84             5.4           3.0            4.5           1.5

# %%
X_test.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 6              4.6           3.4            1.4           0.3
# 3              4.6           3.1            1.5           0.2
# 113            5.7           2.5            5.0           2.0
# 12             4.8           3.0            1.4           0.1
# 24             4.8           3.4            1.9           0.2

# %%
y_train.head()
# Out:
# 126     Iris-virginica
# 23         Iris-setosa
# 64     Iris-versicolor
# 117     Iris-virginica
# 84     Iris-versicolor
# Name: Species, dtype: object

# %%
y_train.head()
# Out:
# 126     Iris-virginica
# 23         Iris-setosa
# 64     Iris-versicolor
# 117     Iris-virginica
# 84     Iris-versicolor
# Name: Species, dtype: object

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # Logistic Regression

# %%
lg = LogisticRegression()

# %%
lg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
lg.coef_,
lg.intercept_
# Out:
# array([  8.76706207,   2.50525554, -11.27231761])

# %% [markdown]
# # Classification Reports

# %%
lg.score(X_test,y_test) * 100
# Out:
# 96.66666666666667

# %%
y_pred = lg.predict(X_test)
y_pred
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-setosa', 'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix (y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[14  0  0]
#  [ 0  7  1]
#  [ 0  0  8]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        14
# Iris-versicolor       1.00      0.88      0.93         8
#  Iris-virginica       0.89      1.00      0.94         8
#
#        accuracy                           0.97        30
#       macro avg       0.96      0.96      0.96        30
#    weighted avg       0.97      0.97      0.97        30
